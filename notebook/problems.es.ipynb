# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# TODO
import random
import numpy as np

experimento = 1000
conteo = 0

for i in range(experimento):
    dado1 = random.randint(1, 6)
    dado2 = random.randint(1, 6)
    dado_total = dado1 + dado2
    if dado_total % 2 == 0 or dado_total > 7:
        conteo += 1

probabilidad = conteo / experimento
print(f"La probabilidad es de:{probabilidad * 100} %")
# Out:
# La probabilidad es de:66.3 %

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import random
import numpy as np

ball_box = {}

# Crea la cajas con las bolas
for i in range(61):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
            
# TODO



experimento = 1000
conteo_1 = 0
conteo_2 = 0

for i in range(experimento):
    bolas= []

    for i in range(5):
            bolas.append(ball_box[random.randint(0, 59)])
    bolas = np.array(bolas)
        
    bolas_blancas = sum(bolas == "White")
    bolas_rojas = sum(bolas == "Red")
    bolas_verdes = sum(bolas == "Green")
    
    if (bolas_blancas == 3) and (bolas_rojas == 2):
         conteo_1 += 1
    if (bolas_blancas == 5) or (bolas_rojas == 5) or (bolas_verdes == 5):
         conteo_2 += 1
    

probabilidad_1 = conteo_1 / experimento 
probabilidad_2 = conteo_2 / experimento

print(f'la probabilidad de que salga 3 bolas blancas y una roja:{probabilidad_1 * 100}%')
print(f'la probabilidad de que salga 5 bolas del mismo color:{probabilidad_2 * 100}%')
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green', 60: 'Green'}
# la probabilidad de que salga 3 bolas blancas y una roja:0.3%
# la probabilidad de que salga 5 bolas del mismo color:3.3000000000000003%

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 13
#      11 for i in range(5):
#      12         bolas.append(ball_box[random.randint(0, 60)])
# ---> 13 if (White== 3) and (Red == 2):
#      14         conteo_1 += 1
#      16 if (White == 5) or (Red == 5) or (Green == 5):
#
# NameError: name 'White' is not defined
